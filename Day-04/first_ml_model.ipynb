# %%
import pandas as pd

data = {
    "Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Marks": [35, 40, 50, 55, 65, 70, 80, 90]
}

df = pd.DataFrame(data)
print(df)

# Feature and target

x = df[["Hours"]]
y = df["Marks"]

from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x, y) 

# Make Prediction

prediction = model.predict([[9]])
print(prediction)

# Visualize it

import matplotlib.pyplot as plt

plt.scatter(x, y)

plt.plot(x, model.predict(x))

plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Hours Vs Marks")

plt.show()

# Another prediction

print(model.predict([[10]]))
# Out:
#    Hours  Marks
# 0      1     35
# 1      2     40
# 2      3     50
# 3      4     55
# 4      5     65
# 5      6     70
# 6      7     80
# 7      8     90
# [95.71428571]
# c:\Users\KIIT0001\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [103.51190476]
# c:\Users\KIIT0001\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Train - Test and split
 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = 0.25,
    random_state = 42
)

print("Training data:")
print(X_train)

print("\nTesting data:")
print(X_test)
# Out:
# Training data:
#    Hours
# 0      1
# 7      8
# 2      3
# 4      5
# 3      4
# 6      7
#
# Testing data:
#    Hours
# 1      2
# 5      6

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Predictions:")
print(predictions)

print("\nActual:")
print(y_test)
# Out:
# Predictions:
# [41.7 72.9]
#
# Actual:
# 1    40
# 5    70
# Name: Marks, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, predictions)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 2.3000000000000007
